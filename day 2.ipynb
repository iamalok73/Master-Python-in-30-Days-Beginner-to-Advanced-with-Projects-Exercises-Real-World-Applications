# %% [markdown]
# # Day 2

# %% [markdown]
# # Agenda
# - Data Type
# - Built-in function

# %%
# Data type in Python 

# Data type in python defind what kind of value  a variable can store and what type of operation can we perform.

# %% [markdown]
# # Numerical Data type
# - int
# - float
# - complex

# %%
a = 10
b = 20
print(a+b)  # Addtion
print(a)
print(type(a))
print(id(a))
print(dir(a))
print(pow(3,3))
# Out:
# 30
# 10
# <class 'int'>
# 140721077073096
# ...

# %%
name_1 = "Amit"
name_2 = "Raju"

print(name_1+name_2)  # concatenation
# Out:
# AmitRaju

# %%
b = 25.5
print(b)
print(type(b))
print(id(b))
# Out:
# 25.5
# <class 'float'>
# 1991411949712

# %%
# type convertion

# %%
c = int(b)
print(c)
print(type(c))

d = complex(b)
print(d)
print(type(d))
# Out:
# 25
# <class 'int'>
# (25.5+0j)
# <class 'complex'>

# %%
e = 3+7j
print(e)
print(type(e))
# Out:
# (3+7j)
# <class 'complex'>

# %%
x = int(e)
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 x = int(e)
#       2 print(x)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
a
# Out:
# 10

# %%
z = float(a)
print(z)
print(type(z))
# Out:
# 10.0
# <class 'float'>

# %% [markdown]
# # Sequece Data type.

# %% [markdown]
# - where mulitple data store in single variable and seperated by comma is called sequece data type.
# -  String -- " "
# - Tuple -- ( )
# - List -- [ ]

# %% [markdown]
# # String Data Type

# %% [markdown]
# - where value bounded by single or double qoutes is called string data type.

# %%
info = "my name is Alok kumar verma."

# %%
print(info)
# Out:
# my name is Alok kumar verma.

# %%
print(type(info))
# Out:
# <class 'str'>

# %%
print(dir(info))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
info.capitalize()
# Out:
# 'My name is alok kumar verma.'

# %%
info.upper()
# Out:
# 'MY NAME IS ALOK KUMAR VERMA.'

# %%
info.lower()
# Out:
# 'my name is alok kumar verma.'

# %%
info.title()
# Out:
# 'My Name Is Alok Kumar Verma.'

# %%
z = info.split()
z
# Out:
# ['my', 'name', 'is', 'Alok', 'kumar', 'verma.']

# %%
# Built-in function--
# len -- count the number of word in string or any data tpye.

# %%
len(info)
# Out:
# 28

# %%
print(len(z))
print(type(z))
# Out:
# 6
# <class 'list'>

# %%
# string have 47 method.

# %%
info.find('a') # where firslty a comes position.
# Out:
# 4

# %%
info.count("a")  # total a in data.
# Out:
# 3

# %%
# in pythin indexing start from 0

# %%
info
# Out:
# 'my name is Alok kumar verma.'

# %%
info[4]
# Out:
# 'a'

# %%
info.replace('A','Z')
# Out:
# 'my name is Zlok kumar verma.'

# %%
info.count("A",'a')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 info.count("A",'a')
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
info.startswith("my")
# Out:
# True

# %%
info.endswith(".")
# Out:
# True

# %%
details = "Delhi"

# %%
a = "Amit"
b = "raju"

# %%
a.join(b)
# Out:
# 'rAmitaAmitjAmitu'

# %%
info.isalnum()
# Out:
# False

# %%
# order me -- abcdef

# %%
d = "zzfawdveskumar"

# %%
d.isalnum()
# Out:
# True

# %%
info.isdigit()
# Out:
# False

# %%
info.partition('name')
# Out:
# ('my ', 'name', ' is Alok kumar verma.')

# %%
info.center(50,"*")
# Out:
# '***********my name is Alok kumar verma.***********'

# %%
info.index("a")
# Out:
# 4

# %%
name = "    Amit    "
print(name)
print(len(name))
# Out:
#     Amit
# 12

# %%
v = name.strip()
print(v)
print(len(v))
# Out:
# Amit
# 4

# %% [markdown]
# # List Data Type

# %%
# List is Sequecne Data type.
# list is mutalbe Data type.
# list can be can  by user.
# list store duplicates values.
# list is also sotre inside list.
# list denoted by [].

# %%
a = [1,1,23,4,5,[11,22,23,34],"String"]

# %%
print(a)
print(type(a))
# Out:
# [1, 1, 23, 4, 5, [11, 22, 23, 34], 'String']
# <class 'list'>

# %%
print(dir(a))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
# append  -- Add at the end

a.append(100)

# %%
print(a)
# Out:
# [1, 1, 23, 4, 5, [11, 22, 23, 34], 'String', 100]

# %%
a.count(1)
# Out:
# 2

# %%
a.pop()
# Out:
# 100

# %%
a.pop()
# Out:
# 'String'

# %%
a
# Out:
# [1, 1, 23, 4, 5, [11, 22, 23, 34]]

# %%
a.remove(23)

# %%
a
# Out:
# [1, 1, 4, 5, [11, 22, 23, 34]]

# %%
a = [1,2,3,4]
b = [4,4,5,6,7,8]

# %%
a.append(b)

# %%
a
# Out:
# [1, 2, 3, 4, [5, 6, 7, 8]]

# %%
a.extend(b)

# %%
a
# Out:
# [1, 2, 3, 4, 4, 4, 5, 6, 7, 8]

# %%
a.insert(0,100)

# %%
a
# Out:
# [100, 1, 2, 3, 4, 4, 4, 5, 6, 7, 8]

# %%
a.reverse()

# %%
a
# Out:
# [8, 7, 6, 5, 4, 4, 4, 3, 2, 1, 100]

# %%
a.sort()

# %%
a.sort(reverse=True)

# %%
a
# Out:
# [100, 8, 7, 6, 5, 4, 4, 4, 3, 2, 1]

# %%
d = a.copy()

# %%
d
# Out:
# [100, 8, 7, 6, 5, 4, 4, 4, 3, 2, 1]

# %%
a.clear()

# %%
a
# Out:
# []

# %% [markdown]
# # Tuple
#
# - Tuple is a also Sequence Data type.
# - Tuple is unmutable data type.
# - in python default data store in tuple.
# - Tuple is deonoted by ()

# %%
a = (1,2,4,7,7,4,23,1)

# %%
print(a)
print(type(a))
# Out:
# (1, 2, 4, 7, 7, 4, 23, 1)
# <class 'tuple'>

# %%
a.count(7)
# Out:
# 2

# %%
a.index(7)
# Out:
# 3

# %%
# Acseeing the data with indexing.

# %%
a = "Amit kumar"

# %%
len(a)
# Out:
# 10

# %%
print(a[0])
# Out:
# A

# %%
print(a[0 : 4])  # 0 in include, 4 4 is excluded.
# Out:
# Amit

# %%
# [start: stop]

# %%
a
# Out:
# 'Amit kumar'

# %%
print(a[0: ])
# Out:
# Amit kumar

# %%
print(a[:4])
# Out:
# Amit

# %%
print(a[:])
# Out:
# Amit kumar

# %%
print(a[: : 2])
# Out:
# Ai ua
