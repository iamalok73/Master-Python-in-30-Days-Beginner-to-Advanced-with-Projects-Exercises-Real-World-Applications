# %% [markdown]
# ### Modules
#
# - its a pre written code.
# - it is reusalbe code of sturcture.
# - multi fucntion at one place
#
# - Modules in python are two type.
#
#     - User Denied modules
#     - Built-in modules

# %% [markdown]
# ### Built-in Modules
# - which is Already created by python Developers aere called Built-in modules.

# %%
# - Random
# - time
# - math
# - cowsay
# -

# %%
import random as r

# %%
# random modules genrate random values

# %%
r.random() # it is give random value bt 0-1
# Out:
# 0.3597348953220614

# %%
r.random()
# Out:
# 0.18778842509262783

# %%
r.random()
# Out:
# 0.41369006704939715

# %%
r.randint(10,20)
# Out:
# 17

# %%
r.randint(10,20)
# Out:
# 18

# %%
r.randrange(2,10,8)
# Out:
# 2

# %%
l = ["Amit","sumit","Rahul","Vivek"]

# %%
r.choice(l)
# Out:
# 'Amit'

# %%
r.choices(l)
# Out:
# ['Vivek']

# %%
d = {1:100,2:200,3:300}

# %%
r.choices(d)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 r.choices(d)
#
# File ~\anaconda3\Lib\random.py:471, in Random.choices(self, population, weights, cum_weights, k)
#     469     floor = _floor
#     470     n += 0.0    # convert to float for a small speed improvement
# --> 471     return [population[floor(random() * n)] for i in _repeat(None, k)]
#     472 try:
#     473     cum_weights = list(_accumulate(weights))
#
# KeyError: 0

# %%
r.sample(l, k=3)
# Out:
# ['Rahul', 'Amit', 'Vivek']

# %%
# math modules

# %%
import math as m

# %%
m.factorial(5)
# Out:
# 120

# %%
m.fabs(-39)
# Out:
# 39.0

# %%
m.modf(56)
# Out:
# (0.0, 56.0)

# %%
m.sqrt(16)
# Out:
# 4.0

# %%
m.sin(90)
# Out:
# 0.8939966636005579

# %%
m.cbrt(64)
# Out:
# 4.0

# %%
import time as t

# %%
t.gmtime()
# Out:
# time.struct_time(tm_year=2026, tm_mon=2, tm_mday=6, tm_hour=16, tm_min=35, tm_sec=37, tm_wday=4, tm_yday=37, tm_isdst=0)

# %%
t.time()
# Out:
# 1770395788.055312

# %%
import datetime as dt

# %%
dt.UTC
# Out:
# datetime.timezone.utc

# %%
dt.timedelta()
# Out:
# datetime.timedelta(0)

# %%
## cowsay

# %%
# !pip install cowsay

# %%
import cowsay as cs

# %%
cs.dragon("d")
# Out:
#   _
# | d |
#   =
#    \
#     \
#      \
#       \
#                             / \\  //\\
#              |\\___/|      /   \\//  \\\\
#              /0  0  \\__  /    //  | \\ \\
#             /     /  \\/_/    //   |  \\  \\
#             \@_^_\@'/   \\/_   //    |   \\   \\
#             //_^_/     \\/_ //     |    \\    \\
#          ( //) |        \\///      |     \\     \\
#        ( / /) _|_ /   )  //       |      \\     _\\
#      ( // /) '/,_ _ _/  ( ; -.    |    _ _\\.-~        .-~~~^-.
#    (( / / )) ,-{        _      `-.|.-~-.           .~         `.
#   (( // / ))  '/\\      /                 ~-. _ .-~      .-~^-.  \\
#   (( /// ))      `.   {            }                   /      \\  \\
#    (( / ))     .----~-.\\        \\-'                 .~         \\  `. \\^-.
#               ///.----..>        \\             _ -~             `.  ^-`  ^-_
#                 ///-._ _ _ _ _ _ _}^ - - - - ~                     ~-- ,.-~
# ...

# %%
cs.pig("p")
# Out:
#   _
# | p |
#   =
#  \
#   \
#    \
#     \
#               ,.
#              (_|,.
#              ,' /, )_______   _
#          __j o``-'        `.'-)'
#          (")                 \'
#          `-j                |
#            `-._(           /
#               |_\  |--^.  /
#              /_]'|_| /_)_/
#                  /_]'  /_]'

# %%
cs.cow("c")
# Out:
#   _
# | c |
#   =
#  \
#   \
#     ^__^
#     (oo)\_______
#     (__)\       )\/\
#         ||----w |
#         ||     ||

# %% [markdown]
# ###  user defined modules
#
# - which is created by user itself class user defined modules
# -
# -  it is Always access only .py file.

# %%
import mod_file as mf

# %%
mf.Alok()
# Out:
# Alok is Data Science Trainner.

# %%
mf.Rakhi()
# Out:
# Rakhi Specilization in Stock marketing.,

# %%
mf.Sarad()
# Out:
# Sarad sir is Full Stack Trainner.

# %%
import mod_file as ms

# %%
ms.Sagar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 ms.Sagar()
#
# AttributeError: module 'mod_file' has no attribute 'Sagar'

# %%
import formula as fm

# %%
a = [1,2,3,4,5,6,7]
fm.list_sum(a)
# Out:
# Total Sum is 28
